# %%
import pandas as pd
import csv as cv

# %%
data = "menu_data.csv"
data2 = "sales_data.csv"

# %%
df = pd.read_csv('menu_data.csv', engine='python')
df2 = pd.read_csv('sales_data.csv', engine='python')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('menu_data.csv', engine='python')
#       2 df2 = pd.read_csv('sales_data.csv', engine='python')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'menu_data.csv'

# %%
df.head(10)

# %%
df2.head(10)

# %%
df.columns
# Out:
# Index(['item', 'category', 'description', 'price', 'cost'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item         32 non-null     object
#  1   category     32 non-null     object
#  2   description  32 non-null     object
#  3   price        32 non-null     float64
#  4   cost         32 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.4+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74124 entries, 0 to 74123
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Line_Item_ID        74124 non-null  int64
#  1   Date                74124 non-null  object
#  2   Credit_Card_Number  74124 non-null  int64
#  3   Quantity            74124 non-null  int64
#  4   Menu_Item           74124 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 2.8+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                               item    category  \
# 0                                          edamame  appetizers
# 1                                      house salad  appetizers
# 2                          cucumber sunomono salad  appetizers
# 3                     hiyashi wakame seaweed salad  appetizers
# 4                                    agedashi tofu  appetizers
# 5                                   hiyayakko tofu  appetizers
# 6                                   pork floss bao  appetizers
# 7                                       kakuni bao  appetizers
# 8                      edamame fried gyoza (vegan)  appetizers
# 9                                      fried gyoza  appetizers
# 10                                        takoyaki  appetizers
# 11                             rock shrimp tempura  appetizers
# 12                         soft-shell crab tempura  appetizers
# 13                            ebi katsu shrimp bao  appetizers
# 14                                    nagomi shoyu      entree
# 15                                      shio ramen      entree
# 16                                spicy miso ramen      entree
# 17                           vegetarian spicy miso      entree
# 18                                 miso crab ramen      entree
# 19                      soft-shell miso crab ramen      entree
# 20                               tori paitan ramen      entree
# 21                                  tonkotsu ramen      entree
# 22                     burnt garlic tonkotsu ramen      entree
# 23  vegetarian curry + king trumpet mushroom ramen      entree
# 24                            truffle butter ramen      entree
# 25                                       green tea      drinks
# 26                                            coke      drinks
# 27                          black sesame ice cream    desserts
# 28                                matcha ice cream    desserts
# 29                           mango mochi ice cream    desserts
# 30                      strawberry mochi ice cream    desserts
# 31                       black sesame creme brulee    desserts
#
#                                           description  price  cost
# 0                    boiled soybeans, maldon sea salt    4.0     1
# 1   mixed greens, cherry tomatoes, cucumber, house...    4.0     2
# 2   cucumber, ponzu dressing, pickled ginger sprou...    5.0     2
# 3   sweet soy-marinated wakame seaweed threads, pi...    5.0     2
# 4   tempura battered tofu, katsuobushi, tsuyu brot...    5.0     2
# 5   chilled soft tofu, house shoyu, katsuobushi, g...    5.0     2
# 6   two steamed buns, minced lean slow braised nim...    4.0     2
# 7   two steamed buns, chopped fatty slow braised n...    6.0     3
# 8   six crispy fried edamame and cabbage pot stick...    6.0     3
# 9   six cripsy fried pork and vegetable pot sticke...    6.0     6
# 10  six octopus-filled fried fritters, kewpie mayo...    6.0     3
# 11  deep fried tempura battered rock shrimp, srira...    6.0     3
# 12  single deep fried soft-shell crab, tsuyu dippi...    6.0     3
# 13  two steamed buns, panko-crusted fried shrimp p...    6.0     3
# 14  shoyu seasoned clear double stock (organic chi...   11.0     5
# 15  sea salt seasoned clear double stock (organic ...   11.0     5
# 16  house togarashi miso blend + niman ranch pork ...   12.0     5
# 17  house togarashi miso blend + vegan dashi; temp...   12.0     5
# 18  house miso crab blend + vegan dashi; slow brai...   12.0     6
# 19  house miso crab blend + vegan dashi; fried who...   14.0     7
# 20  rich, shoyu seasoned double stock (organic chi...   13.0     6
# 21  rich, shoyi seasoned niman ranch pork bone sto...   13.0     6
# 22  rich, shoyi and burnt garlic seasoned niman ra...   14.0     6
# 23  house curry blend + vegan dashi; fried king tr...   13.0     7
# 24  rich, shoyu seasoned niman ranch prok bone sto...   14.0     7
# 25                                          green tea    2.5     1
# 26                                     Coca Cola soda    2.0     1
# 27  house-made black sesame ice cream, valrhona ch...    5.0     2
# 28  house-made matcha ice cream, white chocolate p...    5.0     2
# 29  two rice-cake bonbons filled with strawberry i...    5.0     2
# 30  two rice-cake bonbons filled with strawberry i...    5.0     2
# 31  house made black sesame infused creme brulee; ...    6.0     3  >

# %%
df2.describe()
# Out:
#        Line_Item_ID  Credit_Card_Number      Quantity
# count  74124.000000        7.412400e+04  74124.000000
# mean   37062.500000        4.987993e+15      1.350521
# std    21397.900014        2.883384e+15      0.789305
# min        1.000000        1.637593e+11      1.000000
# 25%    18531.750000        2.498660e+15      1.000000
# 50%    37062.500000        4.993348e+15      1.000000
# 75%    55593.250000        7.468494e+15      1.000000
# max    74124.000000        9.999826e+15      4.000000

# %%
df.isnull().sum()
# Out:
# item           0
# category       0
# description    0
# price          0
# cost           0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Line_Item_ID          0
# Date                  0
# Credit_Card_Number    0
# Quantity              0
# Menu_Item             0
# dtype: int64

# %%
df.shape
# Out:
# (32, 5)

# %%
df2.shape
# Out:
# (74124, 5)

# %%
df.columns
# Out:
# Index(['item', 'category', 'description', 'price', 'cost'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item'], dtype='object')

# %%
df.dtypes
# Out:
# item            object
# category        object
# description     object
# price          float64
# cost             int64
# dtype: object

# %%
df2.dtypes
# Out:
# Line_Item_ID           int64
# Date                  object
# Credit_Card_Number     int64
# Quantity               int64
# Menu_Item             object
# dtype: object

# %%
df2['Menu_Item'].unique()
# Out:
# array(['spicy miso ramen', 'tori paitan ramen', 'truffle butter ramen',
#        'tonkotsu ramen', 'vegetarian spicy miso', 'shio ramen',
#        'miso crab ramen', 'nagomi shoyu', 'soft-shell miso crab ramen',
#        'burnt garlic tonkotsu ramen',
#        'vegetarian curry + king trumpet mushroom ramen'], dtype=object)

# %%
df['item'].unique()
# Out:
# array(['edamame', 'house salad', 'cucumber sunomono salad',
#        'hiyashi wakame seaweed salad', 'agedashi tofu', 'hiyayakko tofu',
#        'pork floss bao', 'kakuni bao', 'edamame fried gyoza (vegan)',
#        'fried gyoza', 'takoyaki', 'rock shrimp tempura',
#        'soft-shell crab tempura', 'ebi katsu shrimp bao', 'nagomi shoyu',
#        'shio ramen', 'spicy miso ramen', 'vegetarian spicy miso',
#        'miso crab ramen', 'soft-shell miso crab ramen',
#        'tori paitan ramen', 'tonkotsu ramen',
#        'burnt garlic tonkotsu ramen',
#        'vegetarian curry + king trumpet mushroom ramen',
#        'truffle butter ramen', 'green tea', 'coke',
#        'black sesame ice cream', 'matcha ice cream',
#        'mango mochi ice cream', 'strawberry mochi ice cream',
#        'black sesame creme brulee'], dtype=object)

# %%
menu_tolist = df.to_dict(orient='records')

# %%
menu_tolist
# Out:
# [{'item': 'edamame',
#   'category': 'appetizers',
#   'description': 'boiled soybeans, maldon sea salt',
#   'price': 4.0,
#   'cost': 1},
#  {'item': 'house salad',
#   'category': 'appetizers',
#   'description': 'mixed greens, cherry tomatoes, cucumber, house ginger dressing',
#   'price': 4.0,
#   'cost': 2},
#  {'item': 'cucumber sunomono salad',
#   'category': 'appetizers',
#   'description': 'cucumber, ponzu dressing, pickled ginger sproud, sesame seeds',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'hiyashi wakame seaweed salad',
#   'category': 'appetizers',
#   'description': 'sweet soy-marinated wakame seaweed threads, pickled ginger sprout, sesame seeds',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'agedashi tofu',
#   'category': 'appetizers',
#   'description': 'tempura battered tofu, katsuobushi, tsuyu broth, scallions',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'hiyayakko tofu',
#   'category': 'appetizers',
#   'description': 'chilled soft tofu, house shoyu, katsuobushi, ginger, scallions',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'pork floss bao',
#   'category': 'appetizers',
#   'description': 'two steamed buns, minced lean slow braised niman, ranch pork belly, cucumbers, sriracha mayo',
#   'price': 4.0,
#   'cost': 2},
#  {'item': 'kakuni bao',
#   'category': 'appetizers',
#   'description': 'two steamed buns, chopped fatty slow braised niman ranch pork belly, cucumbers, house bao sauce',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'edamame fried gyoza (vegan)',
#   'category': 'appetizers',
#   'description': 'six crispy fried edamame and cabbage pot stickers; ponzu rayu dipping sauce',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'fried gyoza',
#   'category': 'appetizers',
#   'description': 'six cripsy fried pork and vegetable pot stickers; ponzu rayu dipping sauce',
#   'price': 6.0,
#   'cost': 6},
#  {'item': 'takoyaki',
#   'category': 'appetizers',
#   'description': 'six octopus-filled fried fritters, kewpie mayo, okonomi sauce, aonori, katsuobushi, nori',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'rock shrimp tempura',
#   'category': 'appetizers',
#   'description': 'deep fried tempura battered rock shrimp, sriracha mayo, nisume sauce, aonori, scallions',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'soft-shell crab tempura',
#   'category': 'appetizers',
#   'description': 'single deep fried soft-shell crab, tsuyu dipping broth',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'ebi katsu shrimp bao',
#   'category': 'appetizers',
#   'description': 'two steamed buns, panko-crusted fried shrimp patties, yuzu-kosho mayo, aonori, scallions',
#   'price': 6.0,
#   'cost': 3},
#  {'item': 'nagomi shoyu',
#   'category': 'entree',
#   'description': 'shoyu seasoned clear double stock (organic chick broth + house dashi); slow braised niman ranch pork belly, hanjuku tamago, nori, menma, scallions',
#   'price': 11.0,
#   'cost': 5},
#  {'item': 'shio ramen',
#   'category': 'entree',
#   'description': 'sea salt seasoned clear double stock (organic chicken broth + house dashi); slow braised niman ranch pork belly, hanjuku tamago, kikurage, nori, scallions',
#   'price': 11.0,
#   'cost': 5},
#  {'item': 'spicy miso ramen',
#   'category': 'entree',
#   'description': 'house togarashi miso blend + niman ranch pork bone stock; slow braised niman ranch pork belly, hanjuku tamago, kikurage, nori, scallions',
#   'price': 12.0,
#   'cost': 5},
#  {'item': 'vegetarian spicy miso',
#   'category': 'entree',
#   'description': 'house togarashi miso blend + vegan dashi; tempura fried tofu, sweet corn, edamame, kikurage, nori, scallions; organic soy milk upon request',
#   'price': 12.0,
#   'cost': 5},
#  {'item': 'miso crab ramen',
#   'category': 'entree',
#   'description': 'house miso crab blend + vegan dashi; slow braised niman ranch pork belly, crab meat, hanjuku tamago, kikurage, nori, scallions',
#   'price': 12.0,
#   'cost': 6},
#  {'item': 'soft-shell miso crab ramen',
#   'category': 'entree',
#   'description': 'house miso crab blend + vegan dashi; fried whole soft-shell crab, hanjuku tamago, kikurage, nori, scallions',
#   'price': 14.0,
#   'cost': 7},
#  {'item': 'tori paitan ramen',
#   'category': 'entree',
#   'description': 'rich, shoyu seasoned double stock (organic chicken broth + house dashi); slow braised niman ranch pork belly, hanuku tamago, kikurage, nori, scllaions',
#   'price': 13.0,
#   'cost': 6},
#  {'item': 'tonkotsu ramen',
#   'category': 'entree',
#   'description': 'rich, shoyi seasoned niman ranch pork bone stock; slow braised niman ranch pork belly, hanjuku tamago, kikurage, nori, spring radish, scallions',
#   'price': 13.0,
#   'cost': 6},
#  {'item': 'burnt garlic tonkotsu ramen',
#   'category': 'entree',
#   'description': 'rich, shoyi and burnt garlic seasoned niman ranch pork bone stock; slow braised niman ranch pork belly, hanjuku tamago, kikurage, sweet corn, nori, scallions',
#   'price': 14.0,
#   'cost': 6},
#  {'item': 'vegetarian curry + king trumpet mushroom ramen',
#   'category': 'entree',
#   'description': 'house curry blend + vegan dashi; fried king trumpet mushroom, tempura fried tofu, mung bean sprouts, kikurage, nori, scallions',
#   'price': 13.0,
#   'cost': 7},
#  {'item': 'truffle butter ramen',
#   'category': 'entree',
#   'description': 'rich, shoyu seasoned niman ranch prok bone stock; truffle compound butter, slow braised niman ranch pork belly, kikurage, sweet corn, nori, scallions',
#   'price': 14.0,
#   'cost': 7},
#  {'item': 'green tea',
#   'category': 'drinks',
#   'description': 'green tea',
#   'price': 2.5,
#   'cost': 1},
#  {'item': 'coke',
#   'category': 'drinks',
#   'description': 'Coca Cola soda',
#   'price': 2.0,
#   'cost': 1},
#  {'item': 'black sesame ice cream',
#   'category': 'desserts',
#   'description': 'house-made black sesame ice cream, valrhona chocolate threads, complimentary hojicha',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'matcha ice cream',
#   'category': 'desserts',
#   'description': 'house-made matcha ice cream, white chocolate pearls; complimentary hojicha',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'mango mochi ice cream',
#   'category': 'desserts',
#   'description': 'two rice-cake bonbons filled with strawberry ice cream; complimentary hojicha',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'strawberry mochi ice cream',
#   'category': 'desserts',
#   'description': 'two rice-cake bonbons filled with strawberry ice cream; complimentary hojicha',
#   'price': 5.0,
#   'cost': 2},
#  {'item': 'black sesame creme brulee',
#   'category': 'desserts',
#   'description': 'house made black sesame infused creme brulee; complimentary hojicha',
#   'price': 6.0,
#   'cost': 3}]

# %% [markdown]
# ### 1. Read the Data

# %%
with open("menu_data.csv", mode='r', newline='') as file:
    csv_reader = cv.reader(file)
    next(csv_reader)
    for row in csv_reader:
        menu_list.append(row)

# %%
for row in menu_list[:10]:
    print(row)
# Out:
# ['edamame', 'appetizers', 'boiled soybeans, maldon sea salt', '4', '1']
# ['house salad', 'appetizers', 'mixed greens, cherry tomatoes, cucumber, house ginger dressing', '4', '2']
# ['cucumber sunomono salad', 'appetizers', 'cucumber, ponzu dressing, pickled ginger sproud, sesame seeds', '5', '2']
# ['hiyashi wakame seaweed salad', 'appetizers', 'sweet soy-marinated wakame seaweed threads, pickled ginger sprout, sesame seeds', '5', '2']
# ['agedashi tofu', 'appetizers', 'tempura battered tofu, katsuobushi, tsuyu broth, scallions', '5', '2']
# ['hiyayakko tofu', 'appetizers', 'chilled soft tofu, house shoyu, katsuobushi, ginger, scallions', '5', '2']
# ['pork floss bao', 'appetizers', 'two steamed buns, minced lean slow braised niman, ranch pork belly, cucumbers, sriracha mayo', '4', '2']
# ['kakuni bao', 'appetizers', 'two steamed buns, chopped fatty slow braised niman ranch pork belly, cucumbers, house bao sauce', '6', '3']
# ['edamame fried gyoza (vegan)', 'appetizers', 'six crispy fried edamame and cabbage pot stickers; ponzu rayu dipping sauce', '6', '3']
# ['fried gyoza', 'appetizers', 'six cripsy fried pork and vegetable pot stickers; ponzu rayu dipping sauce', '6', '6']

# %%
sales_tolist = df2.to_dict(orient='records')
# Out:
# [{'Line_Item_ID': 1,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 7437926611570799,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 2,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 7437926611570799,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 3,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8421920068932819,
#   'Quantity': 3,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 4,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8421920068932819,
#   'Quantity': 3,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 5,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 4787310681569648,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 6,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 4787310681569648,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 7,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8252818705821725,
#   'Quantity': 1,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 8,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8252818705821725,
#   'Quantity': 1,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 9,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 3119034881407323,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 10,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 3119034881407323,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 11,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5185620052605569,
#   'Quantity': 1,
#   'Menu_Item': 'shio ramen'},
#  {'Line_Item_ID': 12,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5185620052605569,
#   'Quantity': 1,
#   'Menu_Item': 'shio ramen'},
#  {'Line_Item_ID': 13,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 1625774198697856,
#   'Quantity': 1,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 14,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 1625774198697856,
#   'Quantity': 1,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 15,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 505248472056578,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 16,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 505248472056578,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 17,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5010864392617689,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 18,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5010864392617689,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 19,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 1792739336416381,
#   'Quantity': 2,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 20,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 1792739336416381,
#   'Quantity': 2,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 21,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 761559936834947,
#   'Quantity': 2,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 22,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 761559936834947,
#   'Quantity': 2,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 23,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9019899875381263,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 24,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9019899875381263,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 25,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8390952377142813,
#   'Quantity': 2,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 26,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8390952377142813,
#   'Quantity': 2,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 27,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8413275554809498,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 28,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 8413275554809498,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 29,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9297729736590973,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 30,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9297729736590973,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 31,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 4842259280240047,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 32,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 4842259280240047,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 33,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 6233521625518921,
#   'Quantity': 4,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 34,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 6233521625518921,
#   'Quantity': 4,
#   'Menu_Item': 'tonkotsu ramen'},
#  {'Line_Item_ID': 35,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 2641214109762946,
#   'Quantity': 4,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 36,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 2641214109762946,
#   'Quantity': 4,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 37,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9499629855503509,
#   'Quantity': 1,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 38,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 9499629855503509,
#   'Quantity': 1,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 39,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5567347994803336,
#   'Quantity': 1,
#   'Menu_Item': 'nagomi shoyu'},
#  {'Line_Item_ID': 40,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 5567347994803336,
#   'Quantity': 1,
#   'Menu_Item': 'nagomi shoyu'},
#  {'Line_Item_ID': 41,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 2210478832955280,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 42,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 2210478832955280,
#   'Quantity': 1,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 43,
#   'Date': '01-01-2017',
#   'Credit_Card_Number': 6129806465248355,
#   'Quantity': 1,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID':

#   'Date': '01-09-2017',
#   'Credit_Card_Number': 9068842705785713,
#   'Quantity': 1,
#   'Menu_Item': 'tori paitan ramen'},
#  {'Line_Item_ID': 981,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 8466386752987953,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 982,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 8466386752987953,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 983,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 6484814446837171,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 984,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 6484814446837171,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 985,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 2714418871103092,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 986,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 2714418871103092,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 987,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 3476161354681878,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 988,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 3476161354681878,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian spicy miso'},
#  {'Line_Item_ID': 989,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 4489127337107245,
#   'Quantity': 2,
#   'Menu_Item': 'nagomi shoyu'},
#  {'Line_Item_ID': 990,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 4489127337107245,
#   'Quantity': 2,
#   'Menu_Item': 'nagomi shoyu'},
#  {'Line_Item_ID': 991,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 7628056994442309,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 992,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 7628056994442309,
#   'Quantity': 1,
#   'Menu_Item': 'spicy miso ramen'},
#  {'Line_Item_ID': 993,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 1148991500538501,
#   'Quantity': 3,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 994,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 1148991500538501,
#   'Quantity': 3,
#   'Menu_Item': 'truffle butter ramen'},
#  {'Line_Item_ID': 995,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 8238629810694149,
#   'Quantity': 1,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 996,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 8238629810694149,
#   'Quantity': 1,
#   'Menu_Item': 'miso crab ramen'},
#  {'Line_Item_ID': 997,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 4617306580689128,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 998,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 4617306580689128,
#   'Quantity': 1,
#   'Menu_Item': 'vegetarian curry + king trumpet mushroom ramen'},
#  {'Line_Item_ID': 999,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 5271092074223024,
#   'Quantity': 4,
#   'Menu_Item': 'soft-shell miso crab ramen'},
#  {'Line_Item_ID': 1000,
#   'Date': '01-09-2017',
#   'Credit_Card_Number': 5271092074223024,
#   'Quantity': 4,
#   'Menu_Item': 'soft-shell miso crab ramen'},
#  ...]

# %%
sales_list = []

# %%
with open("sales_data.csv", mode='r', newline='') as sales_file:
    sales_reader = cv.reader(sales_file)
    next(sales_reader)
    for row in sales_reader:
        sales_list.append(row)

# %%
for row in sales_list[:10]:
    print(row)
# Out:
# ['1', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen']
# ['2', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen']
# ['3', '01-01-2017', '8421920068932819', '3', 'tori paitan ramen']
# ['4', '01-01-2017', '8421920068932819', '3', 'tori paitan ramen']
# ['5', '01-01-2017', '4787310681569648', '1', 'truffle butter ramen']
# ['6', '01-01-2017', '4787310681569648', '1', 'truffle butter ramen']
# ['7', '01-01-2017', '8252818705821725', '1', 'tonkotsu ramen']
# ['8', '01-01-2017', '8252818705821725', '1', 'tonkotsu ramen']
# ['9', '01-01-2017', '3119034881407323', '1', 'vegetarian spicy miso']
# ['10', '01-01-2017', '3119034881407323', '1', 'vegetarian spicy miso']

# %% [markdown]
# ### 2. Manipulate the Data

# %%
report = {}
report
# Out:
# {}

# %%
Quantity = []
Menu_item = []

# %%
for row in sales_list:
    quant = int(row[3])
    item = row[4]

# %%
Quantity.append(quant)
Menu_item.append(item)

# %%
if len(Quantity) > 0:
    print("quantities is populated")
else:
    print("is empty")
# Out:
# quantities is populated

# %%
for sales_item in item:
    if sales_item not in report:
        report[sales_item] = {
            '01-count': 0,
            '02-revenue': 0.0,
            '03-cogs': 0.0,
            '04-profit': 0.0
        }

# %%
if len(report)>0:
    print("yes its here relax")
else:
    print("You can overthink it now")
# Out:
# yes its here relax

# %%
for m in menu_list:
    Item = m[0]
    Price = m[3]
    Cost = m[4]

# %%
def process_sales_data(sales_list, menu_list):
    report = {}
# Process sales data and update the report    
    for sales_row in sales_list:
        sales_item = sales_row[4]# index 4 for "Menu_Item" from the sales data
        quantity = int(sales_row[3])# index 3 for "Quantity" from the sales data
        
        matching_menu_item = None #used None to be stored for matching menu_items later
        
        for menu_row in menu_list:
            item = menu_row[0]# index 0 for "Item" from the menu data
            
            if sales_item == item:
                matching_menu_item = menu_row
                break # once a match is found, loop breaks
        
        if matching_menu_item is not None: #when there are matching menu_items
            price = float(matching_menu_item[3]) # index from the matching_menu_item for price
            cost = float(matching_menu_item[4]) # index from the matching_menu_item for cost
            profit = price - cost
            
            if sales_item not in report: # Check if sales_item is in the report
                report[sales_item] = {
                    '01-count': 0,
                    '02-revenue': 0.0,
                    '03-cogs': 0.0,
                    '04-profit': 0.0
                }
            
            report[sales_item]['01-count'] += quantity
            report[sales_item]['02-revenue'] += price * quantity
            report[sales_item]['03-cogs'] += cost * quantity
            report[sales_item]['04-profit'] += profit * quantity
        else:
            print(f"{sales_item} does not equal any item in the menu data! NO MATCH!")
    
    return report

# %%
sales_report = process_sales_data(sales_list, menu_list)
sales_report
# Out:
# {'spicy miso ramen': {'01-count': 9238,
#   '02-revenue': 110856.0,
#   '03-cogs': 46190.0,
#   '04-profit': 64666.0},
#  'tori paitan ramen': {'01-count': 9156,
#   '02-revenue': 119028.0,
#   '03-cogs': 54936.0,
#   '04-profit': 64092.0},
#  'truffle butter ramen': {'01-count': 8982,
#   '02-revenue': 125748.0,
#   '03-cogs': 62874.0,
#   '04-profit': 62874.0},
#  'tonkotsu ramen': {'01-count': 9288,
#   '02-revenue': 120744.0,
#   '03-cogs': 55728.0,
#   '04-profit': 65016.0},
#  'vegetarian spicy miso': {'01-count': 9216,
#   '02-revenue': 110592.0,
#   '03-cogs': 46080.0,
#   '04-profit': 64512.0},
#  'shio ramen': {'01-count': 9180,
#   '02-revenue': 100980.0,
#   '03-cogs': 45900.0,
#   '04-profit': 55080.0},
#  'miso crab ramen': {'01-count': 8890,
#   '02-revenue': 106680.0,
#   '03-cogs': 53340.0,
#   '04-profit': 53340.0},
#  'nagomi shoyu': {'01-count': 9132,
#   '02-revenue': 100452.0,
#   '03-cogs': 45660.0,
#   '04-profit': 54792.0},
#  'soft-shell miso crab ramen': {'01-count': 9130,
#   '02-revenue': 127820.0,
#   '03-cogs': 63910.0,
#   '04-profit': 63910.0},
#  'burnt garlic tonkotsu ramen': {'01-count': 9070,
#   '02-revenue': 126980.0,
#   '03-cogs': 54420.0,
#   '04-profit': 72560.0},
#  'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8824,
#   '02-revenue': 114712.0,
#   '03-cogs': 61768.0,
#   '04-profit': 52944.0}}

# %%
sales_report['burnt garlic tonkotsu ramen']
# Out:
# {'01-count': 9070,
#  '02-revenue': 126980.0,
#  '03-cogs': 54420.0,
#  '04-profit': 72560.0}

# %%
# Define the output file path
output_file_path = "report.txt"

# Open the file for writing
with open(output_file_path, "w") as file:
    # Iterate over the report dictionary and write each entry to the file
    for sales_item, metrics in report.items():
        file.write(f"{sales_item} {metrics['01-count']} {metrics['02-revenue']} {metrics['03-cogs']} {metrics['04-profit']}\n")

# Print a message to confirm that the data has been written to the file
print(f"Report data has been written to {output_file_path}")
# Out:
# Report data has been written to report.txt
